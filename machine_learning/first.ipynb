# %%
import pandas as pd

my_var = [23,24,25]
print(pd.Series(my_var))

my_var1 = pd.Series(my_var,["first","second","third"])
print(my_var1)


complex_var = {
    "column1" :  [1,2,3 ],
    "column2" : ["nii","si","gi"]

}
multi_columns = pd.Series(complex_var)
print(multi_columns)
# Out:
# 0    23
# 1    24
# 2    25
# dtype: int64
# first     23
# second    24
# third     25
# dtype: int64
# column1        [1, 2, 3]
# column2    [nii, si, gi]
# dtype: object
