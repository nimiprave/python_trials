# %% [markdown]
# Generator function:

# %%
def generator_function(num):
    for item in range(num):
        yield item * 2
        

g = generator_function(100)
print(g)
print(next(g))
print(next(g))
print(next(g))
print(next(g))
# Out:
# <generator object generator_function at 0x0000028A04D68790>
# 0
# 2
# 4
# 6
