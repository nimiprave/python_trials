# %% [markdown]
# Reading the json

# %%
import pandas as pd

json_data = {
    "name": "John",
    "age": 30,
    "salary": 10000   
}

json = pd.Series(json_data)
print(json_data)
# Out:
# {'name': 'John', 'age': 30, 'salary': 10000}

# %%
#Reading from the file, the json should represent a table like structure. Otherwise, the 
import pandas as pd
json_obj = pd.read_json("payload.json")
print(json_obj)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# Disctionary as Json

# %%
import pandas as pd

#dictionary data

data = {
    "Duration": [60, 45, 50, 40, 30, 45, 60, 60, 45, 60],
    "Pulse": [110, 117, 103, 109, 117, 102, 98, 100, 103, 100],
    "Maxpulse": [130, 145, 135, 175, 148, 127, 154, 147, 128, 127],
    "Calories": [409, 479, 340, 282, 406, 300, 374, 253, 334, 321]
}

df = pd.DataFrame(data)
print(df)

#describe the data
print(df.describe())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        45    117       145       479
# 2        50    103       135       340
# 3        40    109       175       282
# 4        30    117       148       406
# 5        45    102       127       300
# 6        60     98       154       374
# 7        60    100       147       253
# 8        45    103       128       334
# 9        60    100       127       321
#         Duration       Pulse    Maxpulse    Calories
# count  10.000000   10.000000   10.000000   10.000000
# mean   49.500000  105.900000  141.600000  349.800000
# std    10.394977    6.967384   15.421486   67.957176
# min    30.000000   98.000000  127.000000  253.000000
# 25%    45.000000  100.500000  128.500000  305.250000
# 50%    47.500000  103.000000  140.000000  337.000000
# 75%    60.000000  109.750000  147.750000  398.000000
# max    60.000000  117.000000  175.000000  479.000000

# %% [markdown]
# Analyzing the data frames

# %%
import pandas as pd

df = pd.read_csv("FIFA23_official_data.csv")

#read the top 10 rows. 
print(df.head(10))
# Out:
#        ID             Name  Age  \
# 0  209658      L. Goretzka   27
# 1  212198  Bruno Fernandes   27
# 2  224334         M. Acuña   30
# 3  192985     K. De Bruyne   31
# 4  224232       N. Barella   25
# 5  212622       J. Kimmich   27
# 6  197445         D. Alaba   30
# 7  187961      22 Paulinho   32
# 8  208333           E. Can   28
# 9  210514     João Cancelo   28
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.net/players/209/658/23_60.png     Germany
# 1  https://cdn.sofifa.net/players/212/198/23_60.png    Portugal
# 2  https://cdn.sofifa.net/players/224/334/23_60.png   Argentina
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 4  https://cdn.sofifa.net/players/224/232/23_60.png       Italy
# 5  https://cdn.sofifa.net/players/212/622/23_60.png     Germany
# 6  https://cdn.sofifa.net/players/197/445/23_60.png     Austria
# 7  https://cdn.sofifa.net/players/187/961/22_60.png      Brazil
# ...
