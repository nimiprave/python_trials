# %% [markdown]
# Trying out the machine learning Algorithm.

# %%
import pandas as pd

#data 
data = {
    "first_name": ["John", "Anna", "Peter", "Linda"],
    "last_name": ["Doe", "Smith", "Jones", "Jones"],
    "scores": [88, 92, 95, 85]
}


# Ensure the correct path to the CSV file
df = pd.DataFrame(data)
print(df.describe())

#a) Print the first row of the DataFrame
print(df.loc[0])

#b) Print the last row of the DataFrame
print(df.loc[df.first_valid_index()])
print(df.loc[df.last_valid_index()])
print(f'The index of the table: {df.index}')

#inserting a new row
df.loc[4] = ['Tom', 'Hanks', 90]
df.loc[df.index.max() + 1] = ['Simon', 'Hankssha', 80]

#d) Print all the rows of the DataFrame
print(df)
# Out:
#           scores
# count   4.000000
# mean   90.000000
# std     4.396969
# min    85.000000
# 25%    87.250000
# 50%    90.000000
# 75%    92.750000
# max    95.000000
# first_name    John
# last_name      Doe
# scores          88
# Name: 0, dtype: object
# first_name    John
# last_name      Doe
# scores          88
# Name: 0, dtype: object
# first_name    Linda
# last_name     Jones
# scores           85
# Name: 3, dtype: object
# The index of the table: RangeIndex(start=0, stop=4, step=1)
#   first_name last_name  scores
# 0       John       Doe      88
# 1       Anna     Smith      92
# 2      Peter     Jones      95
# 3      Linda     Jones      85
# 4        Tom     Hanks      90
# 5      Simon  Hankssha      80

# %% [markdown]
# Code
